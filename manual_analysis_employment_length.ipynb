# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# Config dict to set the logging level
import logging.config
DEFAULT_LOGGING = {
    'version': 1,
    'disable_existing_loggers': False,
    'loggers': {
        '': {
            'level': 'DEBUG',
        },
    }
}

logging.config.dictConfig(DEFAULT_LOGGING)
# Disabling warnings output
import warnings
from sklearn.exceptions import DataConversionWarning, ConvergenceWarning
warnings.filterwarnings(action='ignore', category=DataConversionWarning)
warnings.filterwarnings(action='ignore', category=ConvergenceWarning)
warnings.filterwarnings(action='ignore', category=UserWarning)

#!pip install dowhy
import dowhy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pygraphviz

# %% [markdown]
# ### Step-1. Create a Causal Graph

# %%
df = pd.read_csv('loans_causal_schema.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   emp_length                     9183 non-null   float64
#  1   state                          10000 non-null  object
#  2   homeownership                  10000 non-null  object
#  3   annual_income                  10000 non-null  float64
#  4   debt_to_income                 9976 non-null   float64
#  5   delinq_2y                      10000 non-null  int64
#  6   earliest_credit_line           10000 non-null  int64
#  7   inquiries_last_12m             10000 non-null  int64
#  8   total_credit_lines             10000 non-null  int64
#  9   open_credit_lines              10000 non-null  int64
#  10  total_credit_limit             10000 non-null  int64
#  11  total_credit_utilized          10000 non-null  int64
#  12  total_collection_amount_ever   10000 non-null  int64
#  13  accounts_opened_24m            10000 non-null  int64
#  14  num_satisfactory_accounts      10000 non-null  int64
#  15  num_accounts_120d_past_due     9682 non-null   float64
#  16  num_accounts_30d_past_due      10000 non-null  int64
#  17  num_active_debit_accounts      10000 non-null  int64
#  18  total_debit_limit              10000 non-null  int64
#  19  num_total_cc_accounts          10000 non-null  int64
#  20  num_open_cc_accounts           10000 non-null  int64
#  21  num_cc_carrying_balance        10000 non-null  int64
#  22  num_mort_accounts              10000 non-null  int64
#  23  account_never_delinq_percent   10000 non-null  float64
#  24  public_record_bankrupt         10000 non-null  int64
#  25  loan_amount                    10000 non-null  int64
#  26  term                           10000 non-null  int64
#  27  interest_rate                  10000 non-null  float64
#  28  installment                    10000 non-null  float64
#  29  loan_status                    10000 non-null  object
#  30  balance                        10000 non-null  float64
#  31  paid_total                     10000 non-null  float64
#  32  credit_line_utilization        10000 non-null  float64
#  33  credit_utilization             9998 non-null   float64
#  34  num_accounts_past_due          9682 non-null   float64
#  35  cc_utilization                 10000 non-null  float64
#  36  delinquent_history             10000 non-null  bool
#  37  credit_duration                10000 non-null  int64
#  38  has_credit_inquiries_last_12m  10000 non-null  bool
#  39  has_collection_accounts        10000 non-null  bool
#  40  has_accounts_opened_24m        10000 non-null  bool
#  41  has_bankrupt_history           10000 non-null  bool
#  42  has_past_due_accounts          10000 non-null  bool
#  43  debt_limit_exceded             10000 non-null  bool
#  44  is_bad_loan                    10000 non-null  bool
#  45  is_homeowner                   10000 non-null  bool
# dtypes: bool(9), float64(13), int64(21), object(3)
# memory usage: 2.9+ MB

# %%
#remove unneccessary fields
df.drop(['open_credit_lines', 'total_credit_lines', 
         'total_credit_utilized', 'total_credit_limit',
         'num_accounts_120d_past_due','num_accounts_30d_past_due',
         'num_open_cc_accounts','num_total_cc_accounts',
         ], axis=1, inplace=True)

df.drop(['account_never_delinq_percent','delinq_2y','earliest_credit_line','total_collection_amount_ever',
         'accounts_opened_24m','public_record_bankrupt','num_accounts_past_due','inquiries_last_12m'], axis=1, inplace=True)
df.drop(['loan_status','homeownership'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# emp_length                       817
# state                              0
# annual_income                      0
# debt_to_income                    24
# num_satisfactory_accounts          0
# num_active_debit_accounts          0
# total_debit_limit                  0
# num_cc_carrying_balance            0
# num_mort_accounts                  0
# loan_amount                        0
# term                               0
# interest_rate                      0
# installment                        0
# balance                            0
# paid_total                         0
# credit_line_utilization            0
# credit_utilization                 2
# cc_utilization                     0
# delinquent_history                 0
# credit_duration                    0
# has_credit_inquiries_last_12m      0
# has_collection_accounts            0
# has_accounts_opened_24m            0
# has_bankrupt_history               0
# has_past_due_accounts              0
# debt_limit_exceded                 0
# is_bad_loan                        0
# is_homeowner                       0
# dtype: int64

# %%
# we have to remove/fix missing values
df['debt_to_income'] = df['debt_to_income'].interpolate()
df['credit_utilization'] = df['credit_utilization'].interpolate()
df  = df.dropna()

# %% [markdown]
# ### Step-1. Create a Causal Graph

# %% [markdown]
# #### In this step we will make assumptions and domain knowledge applied to causal graph
# Here are a list of assumptions that have then been translated into a Causal Diagram
#
#
# * employment length, state, homeownership status and annual income play a major role in deciding the status of the loan
#
# * length of employment and the state where borrower lives will definitley affect the anual income.
#
# * homeownership status will play a role in how many mortgage accounts a borrower will have
#
# * In real world, credit duration is usually an indication of the employment duration ('emp_length'-->'credit_duration')
#
# * 'has_bankrupt_history' --> 'has_credit_inquiries_last_12m'
#
# * 'debt_limit_exceded', 'has_past_due_accounts', 'has_collection_accounts', 'delinquent_history' --> 'has_bankrupt_history'
#
# * 'has_bankrupt_history', 'delinquent_history' --> 'is_bad_loan'
#
# * 'credit_line_utilization','credit_utilization', 'cc_utilization' --> 'is_bad_loan'
#
# * 'emp_length' --> 'total_debit_limit'
#
# * 'annual_income' --> 'credit_line_utilization','credit_utilization', 'cc_utilization'
#
#
# 'emp_length', 'state', 'homeownership', 'annual_income',
#        'debt_to_income', 'num_satisfactory_accounts',
#        'num_active_debit_accounts', 'total_debit_limit',
#        'num_cc_carrying_balance', 'num_mort_accounts', 'loan_amount', 'term',
#        'interest_rate', 'installment', 'balance', 'paid_total',
#        'credit_line_utilization_%', 'credit_utilization_%', 'cc_utilization_%',
#        'delinquent_history', 'credit_duration',
#        'has_credit_inquiries_last_12m', 'has_collection_accounts',
#        'has_accounts_opened_24m', 'has_bankrupt_history',
#        'has_past_due_accounts', 'debt_limit_exceded', 'is_bad_loan'

# %%
file = open("causal_graph_employment_length.dot")
causal_graph = file.read().replace("\n", " ")
file.close()

# %%
model= dowhy.CausalModel(
        data = df,
        graph=causal_graph,
        treatment='annual_income',
        outcome='is_bad_loan')
model.view_model()
from IPython.display import Image, display
display(Image(filename="causal_model.png",width = 5000, height = 100))

# %%
model.interpret()

# %% [markdown]
# ### Step-2. Identify the Causal Effect

# %%
identified_estimand = model.identify_effect(proceed_when_unidentifiable=True)
print(identified_estimand)
# Out:
# Estimand type: nonparametric-ate
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#        d
# ────────────────(Expectation(is_bad_loan|debt_to_income,loan_amount,has_past_d
# d[annual_income]
#
#
# ue_accounts,installment,num_satisfactory_accounts,delinquent_history,has_colle
#
#
#
# ction_accounts,state,term,num_mort_accounts,is_homeowner,paid_total,balance,em
#
#
#
# p_length,num_cc_carrying_balance,has_credit_inquiries_last_12m,has_accounts_op
#
#
#
# ened_24m,debt_limit_exceded,has_bankrupt_history,interest_rate))
#
# Estimand assumption 1, Unconfoundedness: If U→{annual_income} and U→is_bad_loan then P(is_bad_loan|annual_income,debt_to_income,loan_amount,has_past_due_accounts,installment,num_satisfactory_accounts,delinquent_history,has_collection_accounts,state,term,num_mort_accounts,is_homeowner,paid_total,balance,emp_length,num_cc_carrying_balance,has_credit_inquiries_last_12m,has_accounts_opened_24m,debt_limit_exceded,has_bankrupt_history,interest_rate,U) = P(is_bad_loan|annual_income,debt_to_income,loan_amount,has_past_due_accounts,installment,num_satisfactory_accounts,delinquent_history,has_collection_accounts,state,term,num_mort_accounts,is_homeowner,paid_total,balance,emp_length,num_cc_carrying_balance,has_credit_inquiries_last_12m,has_accounts_opened_24m,debt_limit_exceded,has_bankrupt_history,interest_rate)
#
# ### Estimand : 2
# Estimand name: iv
# No such variable found!
#
# ### Estimand : 3
# Estimand name: frontdoor
# No such variable found!

# %% [markdown]
# ### Step-3. Estimate the identified estimand

# %%
#'backdoor.propensity_score_stratification','propensity_score_matching','iv.instrumental_variable'
estimates_list = []
methods_list = ['backdoor.linear_regression']
method_param_list = [None] 
for i in range(len(methods_list)):
    print('Estimating--------------->', methods_list[i])
    estimate = model.estimate_effect(identified_estimand,
                                     method_name=methods_list[i],
                                     method_params=method_param_list[i],
                                     target_units="ate",test_significance=True)
    estimates_list.append(estimate)
    print(estimate)
# Out:
# [autoreload of scipy.spatial.kdtree failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 0
# ]
# [autoreload of scipy.spatial.distance failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: _validate_wminkowski_kwargs() requires a code object with 3 free vars, not 0
# ]
# [autoreload of scipy.sparse.linalg.isolve.iterative failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/scipy/sparse/linalg/isolve/iterative.py", line 150, in <module>
#     def bicg(A, b, x0=None, tol=1e-5, maxiter=None, M=None, callback=None, atol=None):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/scipy/_lib/_threadsafety.py", line 57, in decorator
#     return lock.decorate(func)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/scipy/_lib/_threadsafety.py", line 45, in decorate
#     return scipy._lib.decorator.decorate(func, caller)
# AttributeError: module 'scipy' has no attribute '_lib'
# ]
# [autoreload of scipy.stats._continuous_distns failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: fit() requires a code object with 1 free vars, not 0
# ]
# [autoreload of sklearn.utils.fixes failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/sklearn/utils/fixes.py", line 248, in <module>
#     class loguniform(scipy.stats.reciprocal):
# AttributeError: module 'scipy' has no attribute 'stats'
# ]
# [autoreload of sklearn.utils.validation failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: assert_all_finite() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.utils.class_weight failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: compute_class_weight() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.utils failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: safe_sqr() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.base failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: clone() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.utils.extmath failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: safe_sparse_dot() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.utils.sparsefuncs failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: incr_mean_variance_axis() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.preprocessing._function_transformer failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.preprocessing._encoders failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/sklearn/preprocessing/_encoders.py", line 13, in <module>
#     from ._label import _encode, _encode_check_unknown
# ImportError: cannot import name '_encode_check_unknown' from 'sklearn.preprocessing._label' (/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/sklearn/preprocessing/_label.py)
# ]
# [autoreload of sklearn.preprocessing._data failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: scale() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.preprocessing._label failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.preprocessing._discretization failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.linear_model._base failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.linear_model._bayes failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.model_selection._split failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.metrics._ranking failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: average_precision_score() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.metrics._classification failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: accuracy_score() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.metrics.cluster._supervised failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: contingency_matrix() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.metrics.pairwise failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: check_pairwise_arrays() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.metrics.cluster._unsupervised failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: silhouette_score() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.metrics.cluster._bicluster failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: consensus_score() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.metrics._regression failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: mean_absolute_error() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.metrics._scorer failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: check_scoring() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.metrics._plot.roc_curve failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.metrics._plot.precision_recall_curve failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.metrics._plot.confusion_matrix failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.model_selection._validation failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: cross_validate() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.model_selection._search failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.linear_model._least_angle failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: lars_path() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.linear_model._coordinate_descent failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: lasso_path() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.linear_model._huber failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.linear_model._stochastic_gradient failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py", line 25, in <module>
#     from ._sgd_fast import plain_sgd, average_sgd
# ImportError: cannot import name 'plain_sgd' from 'sklearn.linear_model._sgd_fast' (/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/sklearn/linear_model/_sgd_fast.cpython-38-x86_64-linux-gnu.so)
# ]
# [autoreload of sklearn.linear_model._sag failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: sag_solver() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.linear_model._ridge failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/usr/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/usr/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py", line 994, in <module>
#     class _X_CenterStackOp(sparse.linalg.LinearOperator):
# AttributeError: module 'scipy.sparse' has no attribute 'linalg'
# ]
# [autoreload of sklearn.svm._base failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 323, in update_property
#     update_generic(old.fget, new.fget)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: wrapped() requires a code object with 2 free vars, not 0
# ]
# [autoreload of sklearn.svm._classes failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.svm._bounds failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: l1_min_c() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.linear_model._logistic failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.linear_model._omp failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: orthogonal_mp() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.linear_model._passive_aggressive failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 1
# ]
# [autoreload of sklearn.linear_model._perceptron failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 1
# ]
# [autoreload of sklearn.linear_model._ransac failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.linear_model._theil_sen failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.neighbors._base failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
# ...
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 1
# ]
# [autoreload of sklearn.decomposition._nmf failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: non_negative_factorization() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.decomposition._pca failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.decomposition._incremental_pca failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.decomposition._kernel_pca failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.decomposition._dict_learning failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: sparse_encode() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.decomposition._sparse_pca failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.decomposition._truncated_svd failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.decomposition._fastica failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: fastica() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.decomposition._factor_analysis failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.decomposition._lda failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# [autoreload of sklearn.neighbors._nca failed: Traceback (most recent call last):
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/home/bhakthi/PhD/causalai/venv/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 5 free vars, not 0
# ]
# Estimating---------------> backdoor.linear_regression
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: nonparametric-ate
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#        d
# ────────────────(Expectation(is_bad_loan|debt_to_income,loan_amount,has_past_d
# d[annual_income]
#
#
# ue_accounts,installment,num_satisfactory_accounts,delinquent_history,has_colle
#
#
#
# ction_accounts,state,term,num_mort_accounts,is_homeowner,paid_total,balance,em
#
#
#
# p_length,num_cc_carrying_balance,has_credit_inquiries_last_12m,has_accounts_op
#
#
#
# ened_24m,debt_limit_exceded,has_bankrupt_history,interest_rate))
#
# Estimand assumption 1, Unconfoundedness: If U→{annual_income} and U→is_bad_loan then P(is_bad_loan|annual_income,debt_to_income,loan_amount,has_past_due_accounts,installment,num_satisfactory_accounts,delinquent_history,has_collection_accounts,state,term,num_mort_accounts,is_homeowner,paid_total,balance,emp_length,num_cc_carrying_balance,has_credit_inquiries_last_12m,has_accounts_opened_24m,debt_limit_exceded,has_bankrupt_history,interest_rate,U) = P(is_bad_loan|annual_income,debt_to_income,loan_amount,has_past_due_accounts,installment,num_satisfactory_accounts,delinquent_history,has_collection_accounts,state,term,num_mort_accounts,is_homeowner,paid_total,balance,emp_length,num_cc_carrying_balance,has_credit_inquiries_last_12m,has_accounts_opened_24m,debt_limit_exceded,has_bankrupt_history,interest_rate)
#
# ## Realized estimand
# b: is_bad_loan~annual_income+debt_to_income+loan_amount+has_past_due_accounts+installment+num_satisfactory_accounts+delinquent_history+has_collection_accounts+state+term+num_mort_accounts+is_homeowner+paid_total+balance+emp_length+num_cc_carrying_balance+has_credit_inquiries_last_12m+has_accounts_opened_24m+debt_limit_exceded+has_bankrupt_history+interest_rate+annual_income*debt_to_income+annual_income*loan_amount+annual_income*has_past_due_accounts+annual_income*installment+annual_income*num_satisfactory_accounts+annual_income*delinquent_history+annual_income*term+annual_income*has_collection_accounts+annual_income*num_mort_accounts+annual_income*is_homeowner+annual_income*paid_total+annual_income*balance+annual_income*num_cc_carrying_balance+annual_income*has_credit_inquiries_last_12m+annual_income*has_accounts_opened_24m+annual_income*interest_rate+annual_income*debt_limit_exceded+annual_income*has_bankrupt_history
# Target units: ate
#
# ## Estimate
# Mean value: 3.5034710153813986e-08
# p-value: [0.51636945]
# ### Conditional Estimates
# Empty DataFrame
# Columns: []
# Index: []

# %%
#estimate = model.estimate_effect(identified_estimand, 
#                                 method_name="backdoor.linear_regression", test_significance=True)
# ATE = Average Treatment Effect
# ATT = Average Treatment Effect on Treated (i.e. those who were assigned a different room)
# ATC = Average Treatment Effect on Control (i.e. those who were not assigned a different room)
#print(estimate)
# Out:
# *** Causal Estimate ***
#
# ## Identified estimand
# Estimand type: nonparametric-ate
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#        d
# ────────────────(Expectation(is_bad_loan|debt_to_income,loan_amount,has_past_d
# d[annual_income]
#
#
# ue_accounts,installment,num_satisfactory_accounts,delinquent_history,has_colle
#
#
#
# ction_accounts,state,term,num_mort_accounts,is_homeowner,paid_total,balance,em
#
#
#
# p_length,num_cc_carrying_balance,has_credit_inquiries_last_12m,has_accounts_op
#
#
#
# ened_24m,debt_limit_exceded,has_bankrupt_history,interest_rate))
#
# Estimand assumption 1, Unconfoundedness: If U→{annual_income} and U→is_bad_loan then P(is_bad_loan|annual_income,debt_to_income,loan_amount,has_past_due_accounts,installment,num_satisfactory_accounts,delinquent_history,has_collection_accounts,state,term,num_mort_accounts,is_homeowner,paid_total,balance,emp_length,num_cc_carrying_balance,has_credit_inquiries_last_12m,has_accounts_opened_24m,debt_limit_exceded,has_bankrupt_history,interest_rate,U) = P(is_bad_loan|annual_income,debt_to_income,loan_amount,has_past_due_accounts,installment,num_satisfactory_accounts,delinquent_history,has_collection_accounts,state,term,num_mort_accounts,is_homeowner,paid_total,balance,emp_length,num_cc_carrying_balance,has_credit_inquiries_last_12m,has_accounts_opened_24m,debt_limit_exceded,has_bankrupt_history,interest_rate)
#
# ## Realized estimand
# b: is_bad_loan~annual_income+debt_to_income+loan_amount+has_past_due_accounts+installment+num_satisfactory_accounts+delinquent_history+has_collection_accounts+state+term+num_mort_accounts+is_homeowner+paid_total+balance+emp_length+num_cc_carrying_balance+has_credit_inquiries_last_12m+has_accounts_opened_24m+debt_limit_exceded+has_bankrupt_history+interest_rate+annual_income*debt_to_income+annual_income*loan_amount+annual_income*has_past_due_accounts+annual_income*installment+annual_income*num_satisfactory_accounts+annual_income*delinquent_history+annual_income*term+annual_income*has_collection_accounts+annual_income*num_mort_accounts+annual_income*is_homeowner+annual_income*paid_total+annual_income*balance+annual_income*num_cc_carrying_balance+annual_income*has_credit_inquiries_last_12m+annual_income*has_accounts_opened_24m+annual_income*interest_rate+annual_income*debt_limit_exceded+annual_income*has_bankrupt_history
# Target units: ate
#
# ## Estimate
# Mean value: 3.5034710153813986e-08
# p-value: [0.51636945]
# ### Conditional Estimates
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Step-4. Refute results

# %% [markdown]
# ##### Radom Common Cause:
# Adds randomly drawn covariates to data and re-runs the analysis to see if the causal estimate changes or not. If our assumption was originally correct then the causal estimate shouldn’t change by much.

# %%
refuter1=model.refute_estimate(identified_estimand, estimate, method_name="random_common_cause")
print(refuter1)
# Out:
# Refute: Add a Random Common Cause
# Estimated effect:3.5034710153813986e-08
# New effect:3.501273888179002e-08

# %% [markdown]
# #### Placebo Treatment Refuter:
# Randomly assigns any covariate as a treatment and re-runs the analysis. If our assumptions were correct then this newly found out estimate should go to 0.

# %%
refuter2=model.refute_estimate(identified_estimand, estimate, method_name="placebo_treatment_refuter",
                              placebo_type="permute", num_simulations=5)
print(refuter2)
# Out:
# Refute: Use a Placebo Treatment
# Estimated effect:3.5034710153813986e-08
# New effect:7.25689113661998e-10
# p value:0.48604132521318105

# %% [markdown]
# #### Data Subset Refuter:
# Creates subsets of the data(similar to cross-validation) and checks whether the causal estimates vary across subsets. If our assumptions were correct there shouldn’t be much variation.

# %%
refuter3=model.refute_estimate(identified_estimand, estimate,  method_name="data_subset_refuter")
print(refuter3)
# Out:
# Refute: Use a subset of data
# Estimated effect:3.5034710153813986e-08
# New effect:3.5824949783606205e-08
# p value:0.43

# %%
refuter_list = ["placebo_treatment_refuter","data_subset_refuter", "random_common_cause"]
refutation_list = []
inspect_refutations=True
refuter_count = 1

for refuter in refuter_list:
    refute_estimate = model.refute_estimate(identified_estimand, estimate, method_name=refuter)
    refutation_list.append(refute_estimate)

if inspect_refutations is True:
    for refutation in refutation_list:
        print("####### Refutation {}######################################################".format(refuter_count))
        print("*** Class Name ***")
        print()
        print(refutation.refutation_type)
        print()
        print(refutation)
        print("############################################################################")
        print()
        refuter_count += 1
# Out:
# ####### Refutation 1######################################################
# *** Class Name ***
#
# Refute: Use a Placebo Treatment
#
# Refute: Use a Placebo Treatment
# Estimated effect:3.5034710153813986e-08
# New effect:1.1791956300299944e-13
# p value:0.0
#
# ############################################################################
#
# ####### Refutation 2######################################################
# *** Class Name ***
#
# Refute: Use a subset of data
#
# Refute: Use a subset of data
# Estimated effect:3.5034710153813986e-08
# New effect:3.629810918228185e-08
# p value:0.48
#
# ############################################################################
#
# ####### Refutation 3######################################################
# *** Class Name ***
#
# Refute: Add a Random Common Cause
#
# Refute: Add a Random Common Cause
# Estimated effect:3.5034710153813986e-08
# New effect:3.409845312704607e-08
#
# ############################################################################
